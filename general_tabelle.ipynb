# %%
import pandas as pd
import numpy as np
import os
from color_mapping import clean_color_column
from country_mapping import clean_country_column

file_path = os.path.expanduser("~/Desktop/regge.xlsx")
df = pd.read_excel(file_path)

# Clean the color column
df["Farbe"] = clean_color_column(df["Farbe"])

# Clean the condition column
df["Zustand"] = clean_color_column(df["Zustand"])

# %%
categorical_columns = [
    "Zustand",
    "Farbe",
    "Seller Type",
    "Herkunftsland",
    "Verkaufsart",
    "Batteriezustand"
]

tables = {}

for col in categorical_columns:
    tables[col] = frequency_table(df, col)
    print("\n", "="*50)
    print(col)
    display(tables[col])
# Out:
#  ==================================================
# Zustand
#        Zustand  Count  Percent
# 0          neu    156    77.61
# 1    gebraucht     24    11.94
# 2  refurbished     21    10.45
#  ==================================================
# Farbe
#      Farbe  Count  Percent
# 0  schwarz     78    38.81
# 1     blau     36    17.91
# 2     weiß     36    17.91
# 3     lila     29    14.43
# 4     grün     22    10.95
#  ==================================================
# Seller Type
#   Seller Type  Count  Percent
# 0  Gewerblich    125    62.19
# 1      Privat     76    37.81
#  ==================================================
# Herkunftsland
#   Herkunftsland  Count  Percent
# 0   Deutschland    188    93.53
# 1       Italien      9     4.48
# 2    Frankreich      2     1.00
# 3    Österreich      2     1.00
#  ==================================================
# Verkaufsart
#        Verkaufsart  Count  Percent
# 0       Sofortkauf    135    67.16
# 1  Sofortkauf + PR     45    22.39
# 2          Auktion     21    10.45
#  ==================================================
# Batteriezustand
#    Batteriezustand  Count  Percent
# 0            100.0    157    78.11
# 1              NaN     41    20.40
# 2             95.0      2     1.00
# 3             96.0      1     0.50
