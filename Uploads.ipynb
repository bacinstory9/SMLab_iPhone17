# %%
import pandas as pd
import numpy as np
import re
import os #

# %%
file_path = os.path.expanduser("~/Desktop/regge.xlsx")

df = pd.read_excel(file_path)
df.head()
# Out:
#         Preis Verkaufsart      Zustand             Farbe  Batteriezustand  \
# 0  EUR 709,00  Sofortkauf          Neu  Blau - Mist Blue            100.0
# 1  EUR 717,90  Sofortkauf          Neu           Schwarz            100.0
# 2  EUR 923,99  Sofortkauf  Refurbished         nebelblau              NaN
# 3  EUR 923,99  Sofortkauf  Refurbished          lavendel              NaN
# 4  EUR 859,50  Sofortkauf          Neu          Lavender            100.0
#
#    verkauft Verfugbar Herkunftsland     Shop/Seller Seller Rating Seller Type  \
# 0     110.0       NaN   Deutschland       teknotext         99.9%  Gewerblich
# 1     406.0       10+   Deutschland       teknotext         99.9%  Gewerblich
# 2       NaN        10   Deutschland       rebuyshop         99.3%  Gewerblich
# 3       NaN        10   Deutschland       rebuyshop         99.3%  Gewerblich
# 4       NaN       NaN   Deutschland  mediapoint2002             1  Gewerblich
#
# ...
